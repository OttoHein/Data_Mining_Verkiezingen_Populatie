# %%
import findspark
findspark.init()

import pyspark # only run after findspark.init()
from pyspark.sql import SparkSession

#Functionality imports
from pyspark.sql import *
from pyspark.sql.types import *
import folium
from IPython.display import HTML
# %matplotlib inline
import matplotlib.pyplot as plt

sc = SparkSession.builder.getOrCreate()
sqlContext = SQLContext(sc)

df = sc.sql('''select 'spark' as hello ''')
df.show()
# Out:
# +-----+
# |hello|
# +-----+
# |spark|
# +-----+

# %%
#Getting data from csv into dataframe, make sure to have the right location for the csv file
election_data = (sc.sparkContext.textFile('../data/verkiezingen/verkiezingen2014VL.csv')).collect()

#making lists from data
lists = []

for line in election_data:
    if line[-1] ==",":
        line = line[:-1]
    if "PartijNummer" in line:
        lists.append(list)
        list = [] 
    list.append(line)

#Remove empty lists from lists
lists = [x for x in lists if x != []]

#Making new list to add all the dataframes to
dflist = []

#making dataframes from lists
for item in lists:
    #making table structure
    schema = item[0].split(",")
    #structure shouldn't be row
    del(item[0])
    #Need to save the rows before df creation
    rowlist =[]
    #Parsing the rows
    for line in item:
        row = line.split(",")
        rowlist.append(row)
    #Deleting unwanted rows
    for row in rowlist:
        for field in row:
            if field =="":
                del(rowlist[rowlist.index(row)])
                break
    for row in rowlist:
        for field in row:
            if field =="":
                del(rowlist[rowlist.index(row)])
                break
    #Create the dataframe
    df = sqlContext.createDataFrame(rowlist,schema)
    df.show()
    #Add dataframe to list
    dflist.append(df)
# Out:
# +------------+-------------+--------+------+---------+-------+
# |PartijNummer|     Partijen|Geetbets|Linter|Zoutleeuw|Totalen|
# +------------+-------------+--------+------+---------+-------+
# |           2|        Groen|     156|   286|      257|    699|
# |           3|Vlaams Belang|     217|   253|      298|    768|
# |           7|      OpenVld|     904|   871|     1119|   2894|
# |          11|          U F|       0|     3|        3|      6|
# |          12|         sp.a|     692|   667|      914|   2273|
# |          13|         N-VA|    1257|  1488|     1838|   4583|
# |          15|         CD&V|     786|  1348|     1215|   3349|
# |          17|        PVDA+|      63|    72|       90|    225|
# |          29|          VCP|       5|     3|        8|     16|
# |          30| R.O.S.S.E.M.|      13|    13|       22|     48|
# |          33|         ROEL|       5|    10|       10|     25|
# |          34|       GENOEG|      12|    16|       13|     41|
# ...

# %%
#Get results for a municipality function
def get_results_municipality(municipality):
    for df in dflist:
        if municipality in df.columns:
            mundf = df[['Partijen', municipality]]
            break
    return mundf

(get_results_municipality('Avelgem')).show()
# Out:
# +-------------+-------+
# |     Partijen|Avelgem|
# +-------------+-------+
# |        Groen|    413|
# |Vlaams Belang|    296|
# |      OpenVld|   1032|
# |         sp.a|   1427|
# |         N-VA|   1555|
# |         CD&V|   1769|
# |        PVDA+|     84|
# | R.O.S.S.E.M.|     21|
# |         ROEL|      4|
# |       GENOEG|     17|
# |          VCP|     17|
# |Piratenpartij|     42|
# |   V.I.T.A.L.|      3|
# +-------------+-------+

# %%
#Input fields for searching results of a municipality
form = """
 <form action="set_vars()">
  Gemeente:<br>
  <input type="text" id="muni" name="muni"><br><br>
  <input type="submit" value="Submit">
</form> 
"""
javascript = """
<script type="text/Javascript">
    function set_vars(){
        var var_name1 = 'inp_muni';
        var var_value1 = document.getElementById('muni').value;
        var command1 = var_name1 + " = '" + var_value1 + "'";
        var kernel = IPython.notebook.kernel;
        kernel.execute(command1);
        cell = IPython.notebook.get_cell(5);
        cell.execute();
        cell.focus_cell(5);
    }
</script>
"""

HTML(form + javascript)
# Out:
# <div style='background-color:gainsboro; border:solid black; width:300px; padding:20px;'>
# Hour : <input id='hour' type='range' min='3' max='23' step='1' value='4' onchange='set_vars()'/>
# Threshold : <input id='threshold' type='range' min='0' max='20' step='1' value='0' onchange='set_vars()'
# </div>
#
# <script type="text/Javascript">
#     function set_vars(){
#         var var_name1 = 'inp_hour';
#         var var_name2 = 'inp_threshold'
#         var var_value1 = document.getElementById('hour').value;
#         var var_value2 = document.getElementById('threshold').value;
#         var command1 = var_name1 + " = '" + var_value1 + "'";
#         var command2 = var_name2 + " = '" + var_value2 + "'";
#         var kernel = IPython.notebook.kernel;
#         kernel.execute(command1);
#         kernel.execute(command2);
#         cell = IPython.notebook.get_cell(17);
#         cell.execute();
#         cell.focus_cell(17);
#     }
# </script>

# %%
get_results_municipality(inp_muni).show()

# %%
#Center map somewhere in Flanders
electionmap = folium.Map(location=[50.9, 4.25], zoom_start=10)
#Add municipalities overlay & data
electionmap.choropleth(geo_data='../data/verkiezingen/gemeentes.json')

electionmap
