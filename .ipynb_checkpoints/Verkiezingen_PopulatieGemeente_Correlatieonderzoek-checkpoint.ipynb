# %%
import findspark
findspark.init()

import pyspark # only run after findspark.init()
from pyspark.sql import SparkSession
sc = SparkSession.builder.getOrCreate()

import re

df = sc.sql('''select 'spark' as hello ''')
df.show()
# Out:
# +-----+
# |hello|
# +-----+
# |spark|
# +-----+

# %%
def make_election2014_dict(data):
    election2014_dict = {}
    election2014_lines = data.collect()
    for line in election2014_lines:
        re.sub(';','',line)
            
    return election2014_lines

election_data = (sc.sparkContext.textFile('../data/verkiezingen/verkiezingen2014VL.csv'))
s = make_election2014_dict(election_data)

print(s)
# Out:
# ;34003 - Kanton Avelgem;;;;;;;;;;
# ;;;;;;;;;;;
# ;Gemeenten;Avelgem;Spiere-Helkijn;TOTALEN;;;;;;;
# 2;Groen;413;111;524;;;;;;;
# 3;Vlaams Belang;296;50;346;;;;;;;
# 7;OpenVld;1032;308;1340;;;;;;;
# 12;sp.a;1427;237;1664;;;;;;;
# 13;N-VA;1555;206;1761;;;;;;;
# 15;CD&V;1769;278;2047;;;;;;;
# 17;PVDA+;84;17;101;;;;;;;
# 29;R.O.S.S.E.M.;21;5;26;;;;;;;
# 31;ROEL;4;1;5;;;;;;;
# 32;GENOEG;17;3;20;;;;;;;
# 33;VCP;17;6;23;;;;;;;
# 34;Piratenpartij;42;15;57;;;;;;;
# 35;V.I.T.A.L.;3;2;5;;;;;;;
# ;TOTALEN;6680;1239;7919;;;;;;;
# ;31005 - Kanton Brugge;;;;;;;;;;
# ;;;;;;;;;;;
# ;Gemeenten;Beernem;Blankenberge;Brugge;Damme;Jabbeke;Knokke-Heist;Oostkamp;Zedelgem;Zuienkerke;TOTALEN
# 2;Groen;876;693;9112;504;616;1253;1226;1108;117;15505
# 3;Vlaams Belang;448;903;3847;308;452;999;722;800;103;8582
# 7;OpenVld;1468;2502;8623;1057;1026;5076;1760;1452;299;23263
# 12;sp.a;1360;3108;15883;734;1248;1966;2420;2154;227;29100
# 13;N-VA;3234;4200;22058;2594;3001;9561;4846;4622;662;54778
# ...
